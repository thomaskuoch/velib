# %%
from datetime import datetime

import matplotlib.cm as cm
import numpy as np
import pandas as pd
import pydeck as pdk
import requests

pd.set_option("display.max_columns", 100)

# %%
def load(url):
    return requests.get(url).json()

# %%
info = load(
    "https://velib-metropole-opendata.smoove.pro/opendata/Velib_Metropole/station_information.json"
)
status = load(
    "https://velib-metropole-opendata.smoove.pro/opendata/Velib_Metropole/station_status.json"
)

# %%
df_info = pd.DataFrame(info["data"]["stations"]).set_index("station_id")

# %%
df_status = (
    pd.DataFrame(status["data"]["stations"])
    .set_index("station_id")
    .drop(
        columns=[
            "stationCode",
            "num_bikes_available",
            "numBikesAvailable",
            "numDocksAvailable",
        ]
    )
)
df_status["last_reported"] = (
    pd.to_datetime(df_status.last_reported, unit="s", utc=True)
    .dt.tz_convert("Europe/Paris")
    .dt.strftime("%Y-%m-%d %H:%M")
)

# %%
def count_available_mechanical_and_ebike_bikes(data):
    mechanical = data[0]["mechanical"]
    ebike = data[1]["ebike"]
    return mechanical, ebike

# %%
df_status[
    ["num_bikes_available_mechanical", "num_bikes_available_ebike"]
] = pd.DataFrame(
    df_status.num_bikes_available_types.apply(
        count_available_mechanical_and_ebike_bikes
    ).tolist(),
    index=df_status.index,
)

# %%
df = df_info.join(df_status)
df["available_rate"] = (
    (df.num_bikes_available_mechanical + df.num_bikes_available_ebike)
    / df.capacity
).fillna(0)
df["available_rate_format"] = (df.available_rate * 100).astype(int).astype(str)

# %%
df.head(10)
# Out:
#                                             name        lat       lon  \
# station_id
# 213688169          Benjamin Godard - Victor Hugo  48.865983  2.275725
# 653222953              Mairie de Rosny-sous-Bois  48.871257  2.486581
# 36255                         Toudouze - Clauzel  48.879296  2.337360
# 37815204                         Mairie du 12ème  48.840855  2.387555
# 17278902806           Rouget de L'isle - Watteau  48.778193  2.396302
# 251039991            Cassini - Denfert-Rochereau  48.837526  2.336035
# 85002689                Jourdan - Stade Charléty  48.819428  2.343335
# 2515829865                             Basilique  48.936269  2.358867
# 516709288    Charonne - Robert et Sonia Delaunay  48.855908  2.392571
# 120827885               Messine - Place Du Pérou  48.875448  2.315508
#
#              capacity stationCode rental_methods  \
# station_id
# 213688169          35       16107            NaN
# 653222953          30       31104   [CREDITCARD]
# 36255              21        9020   [CREDITCARD]
# 37815204           30       12109            NaN
# 17278902806         0       44015            NaN
# 251039991          25       14111   [CREDITCARD]
# 85002689           60       14014   [CREDITCARD]
# 2515829865         22       32017   [CREDITCARD]
# 516709288          20       11104            NaN
# 120827885          12        8026   [CREDITCARD]
#
#                       num_bikes_available_types  num_docks_available  \
# station_id
# 213688169     [{'mechanical': 2}, {'ebike': 1}]                   31
# 653222953    [{'mechanical': 8}, {'ebike': 16}]                    4
# 36255         [{'mechanical': 1}, {'ebike': 2}]                   18
# 37815204      [{'mechanical': 0}, {'ebike': 0}]                   28
# 17278902806   [{'mechanical': 0}, {'ebike': 0}]                    0
# 251039991     [{'mechanical': 2}, {'ebike': 1}]                   21
# 85002689     [{'mechanical': 17}, {'ebike': 7}]                   32
# 2515829865    [{'mechanical': 3}, {'ebike': 2}]                   16
# 516709288     [{'mechanical': 1}, {'ebike': 2}]                   16
# 120827885     [{'mechanical': 7}, {'ebike': 5}]                    0
#
#              is_installed  is_returning  is_renting     last_reported  \
# station_id
# 213688169               1             1           1  2023-05-25 09:12
# 653222953               1             1           1  2023-05-25 09:14
# 36255                   1             1           1  2023-05-25 09:14
# 37815204                1             1           1  2023-05-25 09:12
# 17278902806             0             0           0  2023-02-09 10:35
# 251039991               1             1           1  2023-05-25 09:12
# 85002689                1             1           1  2023-05-25 09:15
# 2515829865              1             1           1  2023-05-25 09:14
# 516709288               1             1           1  2023-05-25 09:14
# 120827885               1             1           1  2023-05-25 09:15
#
#              num_bikes_available_mechanical  num_bikes_available_ebike  \
# station_id
# 213688169                                 2                          1
# 653222953                                 8                         16
# 36255                                     1                          2
# 37815204                                  0                          0
# 17278902806                               0                          0
# 251039991                                 2                          1
# 85002689                                 17                          7
# 2515829865                                3                          2
# 516709288                                 1                          2
# 120827885                                 7                          5
#
#              available_rate available_rate_format
# station_id
# 213688169          0.085714                     8
# 653222953          0.800000                    80
# 36255              0.142857                    14
# 37815204           0.000000                     0
# 17278902806        0.000000                     0
# 251039991          0.120000                    12
# 85002689           0.400000                    40
# 2515829865         0.227273                    22
# 516709288          0.150000                    15
# 120827885          1.000000                   100

# %%
def to_rgb(x, colormap):
    return np.around((np.array(colormap(x)) * 255)).tolist()


RED_OVER = (np.around(cm.Reds.get_over() * 255)).tolist()

df["color"] = df.available_rate.apply(lambda x: to_rgb(x, cm.RdYlGn))
df["color_ebike"] = (df.num_bikes_available_ebike / 10).apply(
    lambda x: to_rgb(x, cm.winter_r) if x > 0 else RED_OVER
)

df["color_mechanical"] = (df.num_bikes_available_mechanical / 10).apply(
    lambda x: to_rgb(x, cm.summer_r) if x > 0 else RED_OVER
)

# %%
PARIS_LATITUDE = 48.856614
PARIS_LONGITUDE = 2.3522219

WHAT_WE_WANT_TO_SEE = "color_ebike"  # "color_ebike", "color_mechanical" or "color" (for all bikes)


map_style = pdk.map_styles.DARK
initial_view_state = pdk.ViewState(
    latitude=PARIS_LATITUDE,
    longitude=PARIS_LONGITUDE,
    zoom=11.25,
)
layer = pdk.Layer(
    "ScatterplotLayer",
    data=df[df.is_installed == 1],  # drop disconnected velib stations
    get_position="[lon, lat]",
    get_fill_color=WHAT_WE_WANT_TO_SEE,
    get_radius=30,
    pickable=True,
    filled=True,
)
layers = [layer]
pdk_obj = pdk.Deck(
    map_style=map_style,
    initial_view_state=initial_view_state,
    layers=layers,
    tooltip={
        "text": """{name}
            Mechanical bikes: {num_bikes_available_mechanical}
            Ebikes : {num_bikes_available_ebike}
            Availability rate: {available_rate_format}%
            Last update: {last_reported}
            """,
    },
)

# %%
pdk_obj.to_html(f"velib_{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}.html")
# Out:
#         <iframe
#             width="100%"
#             height=500
#             frameborder="0"
#             srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
#   &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;title&gt;pydeck&lt;/title&gt;
#         &lt;script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.13.0/mapbox-gl.js&quot;&gt;&lt;/script&gt;
#         &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot; /&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot; /&gt;
#     &lt;script src=&#x27;https://cdn.jsdelivr.net/npm/@deck.gl/jupyter-widget@~8.8.*/dist/index.js&#x27;&gt;&lt;/script&gt;
#     &lt;style&gt;
#     body {
#   margin: 0;
#   padding: 0;
#   overflow: hidden;
# }
#
# #deck-container {
#   width: 100vw;
#   height: 100vh;
# }
#
# #deck-container canvas {
#   z-index: 1;
#   background: none;
# }
#     &lt;/style&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;deck-container&quot;&gt;
#     &lt;/div&gt;
#   &lt;/body&gt;
#   &lt;script&gt;
#     const container = document.getElementById(&#x27;deck-container&#x27;);
#     const jsonInput = {
#   &quot;initialViewState&quot;: {
#     &quot;latitude&quot;: 48.856614,
#     &quot;longitude&quot;: 2.3522219,
#     &quot;zoom&quot;: 11.25
#   },
#   &quot;layers&quot;: [
#     {
#       &quot;@@type&quot;: &quot;ScatterplotLayer&quot;,
#       &quot;data&quot;: [
#         {
#           &quot;available_rate&quot;: 0.08571428571428572,
#           &quot;available_rate_format&quot;: &quot;8&quot;,
#           &quot;capacity&quot;: 35,
#           &quot;color&quot;: [
#             206.0,
#             40.0,
#             39.0,
#             255.0
#           ],
#           &quot;color_ebike&quot;: [
#             0.0,
#             230.0,
#             140.0,
#             255.0
#           ],
#           &quot;color_mechanical&quot;: [
#             204.0,
#             230.0,
#             102.0,
#             255.0
#           ],
#           &quot;is_installed&quot;: 1,
#           &quot;is_renting&quot;: 1,
#           &quot;is_returning&quot;: 1,
#           &quot;last_reported&quot;: &quot;2023-05-25 09:12&quot;,
#           &quot;lat&quot;: 48.865983,
#           &quot;lon&quot;: 2.275725,
#           &quot;name&quot;: &quot;Benjamin Godard - Victor Hugo&quot;,
#           &quot;num_bikes_available_ebike&quot;: 1,
#           &quot;num_bikes_available_mechanical&quot;: 2,
#           &quot;num_bikes_available_types&quot;: [
#             {
#               &quot;mechanical&quot;: 2
#             },
#             {
#               &quot;ebike&quot;: 1
#             }
#           ],
#           &quot;num_docks_available&quot;: 31,
#           &quot;rental_methods&quot;: NaN,
#           &quot;stationCode&quot;: &quot;16107&quot;
#         },
#         {
#           &quot;available_rate&quot;: 0.8,
#           &quot;available_rate_format&quot;: &quot;80&quot;,
#           &quot;capacity&quot;: 30,
#           &quot;color&quot;: [
#             102.0,
#             189.0,
#             99.0,
#             255.0
#           ],
#           &quot;color_ebike&quot;: [
#             0.0,
#             0.0,
#             255.0,
#             255.0
#           ],
#           &quot;color_mechanical&quot;: [
#             51.0,
#             153.0,
#             102.0,
#             255.0
#           ],
#           &quot;is_installed&quot;: 1,
#           &quot;is_renting&quot;: 1,
#           &quot;is_returning&quot;: 1,
#           &quot;last_reported&quot;: &quot;2023-05-25 09:14&quot;,
#           &quot;lat&quot;: 48.871256519012,
#           &quot;lon&quot;: 2.4865807592869,
#           &quot;name&quot;: &quot;Mairie de Rosny-sous-Bois&quot;,
#           &quot;num_bikes_available_ebike&quot;: 16,
#           &quot;num_bikes_available_mechanical&quot;: 8,
#           &quot;num_bikes_available_types&quot;: [
#             {
#               &quot;mechanical&quot;: 8
#             },
#             {
#               &quot;ebike&quot;: 16
#             }
#           ],
#           &quot;num_docks_available&quot;: 4,
#           &quot;rental_methods&quot;: [
#             &quot;CREDITCARD&quot;
#           ],
#           &quot;stationCode&quot;: &quot;31104&quot;
#         },
#         {
#           &quot;available_rate&quot;: 0.14285714285714285,
#           &quot;available_rate_format&quot;: &quot;14&quot;,
#           &quot;capacity&quot;: 21,
#           &quot;color&quot;: [
#             227.0,
#             73.0,
#             51.0,
#             255.0
#           ],
#           &quot;color_ebike&quot;: [
#             0.0,
#             204.0,
#             153.0,
#             255.0
#           ],
#           &quot;color_mechanical&quot;: [
#             230.0,
#             242.0,
#             102.0,
#             255.0
#           ],
#           &quot;is_installed&quot;: 1,
#           &quot;is_renting&quot;: 1,
#           &quot;is_returning&quot;: 1,
#           &quot;last_reported&quot;: &quot;2023-05-25 09:14&quot;,
#           &quot;lat&quot;: 48.87929591733507,
#           &quot;lon&quot;: 2.3373600840568547,
#           &quot;name&quot;: &quot;Toudouze - Clauzel&quot;,
#           &quot;num_bikes_available_ebike&quot;: 2,
#           &quot;num_bikes_available_mechanical&quot;: 1,
#           &quot;num_bikes_available_types&quot;: [
#             {
#               &quot;mechanical&quot;: 1
#             },
#             {
#               &quot;ebike&quot;: 2
#             }
#           ],
#           &quot;num_docks_available&quot;: 18,
#           &quot;rental_methods&quot;: [
#             &quot;CREDITCARD&quot;
#           ],
#           &quot;stationCode&quot;: &quot;9020&quot;
#         },
#         {
#           &quot;available_rate&quot;: 0.0,
#           &quot;available_rate_format&quot;: &quot;0&quot;,
#           &quot;capacity&quot;: 30,
#           &quot;color&quot;: [
#             165.0,
#             0.0,
#             38.0,
#             255.0
#           ],
#           &quot;color_ebike&quot;: [
#             103.0,
#             0.0,
#             13.0,
#             255.0
#           ],
#           &quot;color_mechanical&quot;: [
#             103.0,
#             0.0,
#             13.0,
#             255.0
#           ],
#           &quot;is_installed&quot;: 1,
#           &quot;is_renting&quot;: 1,
#           &quot;is_returning&quot;: 1,
#           &quot;last_reported&quot;: &quot;2023-05-25 09:12&quot;,
#           &quot;lat&quot;: 48.840855311763,
#           &quot;lon&quot;: 2.3875549435616,
#           &quot;name&quot;: &quot;Mairie du 12\u00e8me&quot;,
#           &quot;num_bikes_available_ebike&quot;: 0,
#           &quot;num_bikes_available_mechanical&quot;: 0,
#           &quot;num_bikes_available_types&quot;: [
#             {
#               &quot;mechanical&quot;: 0
#             },
#             {
#               &quot;ebike&quot;: 0
#             }
#           ],
#           &quot;num_docks_available&quot;: 28,
#           &quot;rental_methods&quot;: NaN,
#           &quot;stationCode&quot;: &quot;12109&quot;
#         },
#         {
#           &quot;available_rate&quot;: 0.12,
#           &quot;available_rate_format&quot;: &quot;12&quot;,
#           &quot;capacity&quot;: 25,
#           &quot;color&quot;: [
#             220.0,
#             59.0,
#             44.0,
#             255.0
#           ],
#           &quot;color_ebike&quot;: [
#             0.0,
#             230.0,
#             140.0,
#             255.0
#           ],
#           &quot;color_mechanical&quot;: [
#             204.0,
#             230.0,
#             102.0,
#             255.0
#           ],
#           &quot;is_installed&quot;: 1,
#           &quot;is_renting&quot;: 1,
#           &quot;is_returning&quot;: 1,
#           &quot;last_reported&quot;: &quot;2023-05-25 09:12&quot;,
#           &quot;lat&quot;: 48.837525839067,
#           &quot;lon&quot;: 2.3360354080796,
#           &quot;name&quot;: &quot;Cassini - Denfert-Rochereau&quot;,
#           &quot;num_bikes_available_ebike&quot;: 1,
#           &quot;num_bikes_available_mechanical&quot;: 2,
#           &quot;num_bikes_available_types&quot;: [
#             {
#               &quot;mechanical&quot;: 2
#             },
#             {
#               &quot
